# %% [markdown]
# # Week 9: Email Prioritization
#
# Use the OpenAI API to classify emails by priority.

# %%
import openai
import pandas as pd
from config import API_KEY

# %%
df = pd.read_csv("your_file_location", encoding="latin-1")

# %% [markdown]
# ## Task 1: System Prompt
#
# Design a system prompt for email classification.

# %%
system_prompt = "<-- YOUR SYSTEM PROMPT GOES HERE -->"

# %% [markdown]
# ## Task 2: User Prompt
#
# Create a user prompt template.

# %%
user_prompt = "<-- YOUR USER PROMPT GOES HERE -->"

# %% [markdown]
# ## Task 3: Analysis
#
# **Your answer here**

# %%
# Sample output from a previous run
