# %% [markdown]
# # Demo Assignment: Basic Python Operations
#
# This notebook tests the notebook-processor pipeline.
# Complete the TODO cells below.

# %% [markdown]
# ## Part 1: Arithmetic
#
# Implement a function that computes the factorial of a non-negative integer.

# %%
# TODO: Implement the factorial function
def factorial(n: int) -> int:
    """Return the factorial of n (n >= 0)."""
    raise NotImplementedError("Complete this function")

# %%
# Verification cell — do not modify
assert factorial(0) == 1
assert factorial(5) == 120
assert factorial(10) == 3628800
print("All factorial tests passed!")

# %% [markdown]
# ## Part 2: String Processing
#
# Implement a function that counts word frequencies in a text.

# %%
# TODO: Implement word frequency counter
def word_frequencies(text: str) -> dict[str, int]:
    """Return a dict mapping each lowercase word to its count.

    Words are split on whitespace. Punctuation should be stripped.
    """
    # YOUR CODE HERE
    pass

# %%
# Verification cell — do not modify
result = word_frequencies("The cat sat on the mat. The cat is happy.")
assert result["the"] == 3
assert result["cat"] == 2
assert result["happy"] == 1
assert "mat" in result
print(f"Word frequencies: {result}")
print("All word frequency tests passed!")

# %% [markdown]
# ## Part 3: Analysis Question
#
# **Question:** What is the time complexity of your `word_frequencies` implementation? Explain your reasoning.
#
# **Your answer here:**

# %% [markdown]
# ## Part 4: Data Structures
#
# Implement a function that finds the two numbers in a list that sum to a target value.

# %%
# TODO: Implement two-sum finder
def two_sum(numbers: list[int], target: int) -> tuple[int, int] | None:
    """Find two numbers that sum to target.

    Returns a tuple of the two numbers, or None if no pair exists.
    The same element cannot be used twice.
    """
    raise NotImplementedError

# %%
# Verification cell — do not modify
result = two_sum([2, 7, 11, 15], 9)
assert result is not None
assert sum(result) == 9
assert two_sum([1, 2, 3], 10) is None
print(f"Two-sum result: {result}")
print("All two-sum tests passed!")

# %% [markdown]
# ## Part 5: Reflection
#
# **Question:** Compare the brute-force O(n²) approach vs the hash-map O(n) approach for the two-sum problem. When might the brute-force approach actually be preferable?
#
# **YOUR ANSWER HERE**

# %% [markdown]
# ---
# *End of assignment.*
