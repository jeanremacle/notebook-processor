# %% [markdown]
# # Sample Assignment
#
# This is a minimal JHU-style notebook for testing the ingestion tool.

# %%
import pandas as pd
df = pd.read_csv("your_file_location", index_col="id", encoding='latin-1')
df

# %% [markdown]
# ## Task 1: Summarize the Data
#
# Write a system prompt that instructs the AI to summarize the dataset.

# %%
# @title System Prompt
system_prompt = """

<-- YOUR SYSTEM PROMPT GOES HERE -->

"""

# %%
# @title User Prompt
user_prompt = f"""

<-- YOUR USER PROMPT GOES HERE -->

Data:
```
{df.to_string()}
```
"""

# %% [markdown]
# ### Sample Output
#
# Sample Output

# %% [markdown]
# ## Task 2: Reflection
#
# `<Enter your summary here>`
